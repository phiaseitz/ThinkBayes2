# %%
import thinkstats2
import thinkplot

# %%
d6 = thinkbayes2.Pmf(range(1,7))

# %%
thinkplot.Hist(d6)

# %%
thinkplot.Pmf(d6)

# %%
thinkplot.Pdf(d6)

# %%
twoDice = d6 + d6

# %%
thinkplot.Hist(twoDice)

# %%
threeDice = twoDice + d6

# %%
thinkplot.Hist(threeDice)

# %%
fourDice = threeDice + d6

# %%
thinkplot.Hist(fourDice)

# %%
fiveDice = fourDice + d6

# %%
thinkplot.Hist(fiveDice)

# %%
thinkplot.Pdfs([d6, twoDice, threeDice, fourDice, fiveDice])

# %%
print threeDice.Mean()
# Out:
# 10.5

# %%
print threeDice.Var()
# Out:
# 8.75

# %%
print thinkstats2.Std(threeDice)
# Out:
# 0.0467820294302

# %%
threeDice.ProbGreater(15)
# Out:
# 0.046296296296296294

# %%
threeDice.Random()
# Out:
# 12
